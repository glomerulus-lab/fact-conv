# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sweep_data.txt', sep=" ", header=0)
df
# Out:
#      s    f    loss  loss_err  accuracy  accuracy_err
# 0    1  0.1  1.0122    0.0062     65.75          0.27
# 1    2  0.1  1.0045    0.0043     65.86          0.06
# 2    3  0.1  1.0125    0.0035     65.51          0.12
# 3    4  0.1  1.0315    0.0220     64.66          0.75
# 4    5  0.1  1.0101    0.0078     65.77          0.23
# 5    6  0.1  1.0105    0.0060     65.70          0.17
# 6   10  0.1  1.0081    0.0025     65.77          0.03
# 7    1  0.5  1.0295    0.0053     65.09          0.21
# 8    2  0.5  1.0257    0.0023     65.26          0.09
# 9    3  0.5  1.0170    0.0065     65.31          0.39
# 10   4  0.5  1.0134    0.0063     65.37          0.21
# 11   5  0.5  1.0158    0.0079     65.31          0.34
# 12   6  0.5  1.0201    0.0047     65.29          0.23
# 13  10  0.5  1.0134    0.0040     65.50          0.09
# 14   1  1.0  1.0411    0.0084     64.25          0.32
# 15   2  1.0  1.0378    0.0067     64.49          0.14
# ...

# %%
print("Max accuracy: ", max(df["accuracy"]))
print("Min loss: ", min(df["loss"]))
# Out:
# Max accuracy:  65.86
# Min loss:  1.0045

# %%
print("Mean accuracy: ", np.mean(df["accuracy"]))
# Out:
# Mean accuracy:  63.36061224489796
